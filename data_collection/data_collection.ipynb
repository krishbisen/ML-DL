# %%
import requests

# %%
url = "https://stephen-king-api.onrender.com/api/books"
res = requests.get(url)

# %%
json_data = res.json()

# %%
import pandas as pd 
df  = pd.json_normalize(json_data["data"])

# %%
df
# Out:
#     id  Year          Title         handle        Publisher  \
# 0    1  1974         Carrie         carrie        Doubleday
# 1    2  1975    Salem's Lot    salem-s-lot        Doubleday
# 2    3  1977    The Shining    the-shining        Doubleday
# 3    4  1977           Rage           rage     Signet Books
# 4    5  1978      The Stand      the-stand        Doubleday
# ..  ..   ...            ...            ...              ...
# 58  59  2018   The Outsider   the-outsider         Scribner
# 59  60  2018      Elevation      elevation         Scribner
# 60  61  2019  The Institute  the-institute         Scribner
# 61  62  2021          Later          later  Hard Case Crime
# 62  63  2021  Billy Summers  billy-summers         Scribner
#
#                  ISBN  Pages  \
# 0   978-0-385-08695-0    199
# 1   978-0-385-00751-1    439
# 2   978-0-385-12167-5    447
# 3   978-0-451-07645-8    211
# 4   978-0-385-12168-2    823
# ..                ...    ...
# 58  978-1-50118-098-9    576
# ...

# %%
df = df[['id','Title','Year','ISBN']]

# %%
df
# Out:
#     id          Title  Year               ISBN
# 0    1         Carrie  1974  978-0-385-08695-0
# 1    2    Salem's Lot  1975  978-0-385-00751-1
# 2    3    The Shining  1977  978-0-385-12167-5
# 3    4           Rage  1977  978-0-451-07645-8
# 4    5      The Stand  1978  978-0-385-12168-2
# ..  ..            ...   ...                ...
# 58  59   The Outsider  2018  978-1-50118-098-9
# 59  60      Elevation  2018  978-1-98210-231-9
# 60  61  The Institute  2019  978-1-98211-056-7
# 61  62          Later  2021  978-1-78909-649-1
# 62  63  Billy Summers  2021  978-1-982-17361-6
#
# [63 rows x 4 columns]

# %%
import requests
import pandas as pd

url2 = "https://dog.ceo/api/breeds/image/random"
res = requests.get(url2)
json_data = res.json()

# Create DataFrame from the entire response
df = pd.DataFrame([json_data])

print(df)
# Out:
#                                              message   status
# 0  https://images.dog.ceo/breeds/ovcharka-caucasi...  success

# %%
url3 =' https://github.com/cyberboysumanjay/Inshorts-News-API'
res = requests.get(url3)
res
# Out:
# <Response [200]>

# %%
json_data = res.json()
json_data
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     977 try:
# --> 978     return complexjson.loads(self.text, **kwargs)
#     979 except JSONDecodeError as e:
#     980     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     981     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %%
url = "https://inshorts-news-api.vercel.app/news?category=technology"
res = requests.get(url)
data = res.json()
print(data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     977 try:
# --> 978     return complexjson.loads(self.text, **kwargs)
#     979 except JSONDecodeError as e:
#     980     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     981     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...
