# %%
import requests
url = 'https://www.scrapethissite.com/pages/simple/'

# %%
res = requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %%
import pandas as pd
json_data  = normalize_data()

# %%
if res.status_code ==200:
    print(res.headers)
with open("scraped_data/data1.html", "w", encoding="utf-8", errors="ignore") as f:
    f.write(res.text)
# Out:
# {'Date': 'Sun, 03 May 2026 19:46:33 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'Report-To': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=vg%2FEHqTTZfwN9hoG5jzfP8Uknr8Mb6sMoSaPyhAHiP4%3D\\u0026sid=67ff5de4-ad2b-4112-9289-cf96be89efed\\u0026ts=1777837593"}],"max_age":3600}', 'Reporting-Endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=vg%2FEHqTTZfwN9hoG5jzfP8Uknr8Mb6sMoSaPyhAHiP4%3D&sid=67ff5de4-ad2b-4112-9289-cf96be89efed&ts=1777837593"', 'Server': 'cloudflare', 'Via': '1.1 heroku-router', 'cf-cache-status': 'DYNAMIC', 'Content-Encoding': 'zstd', 'CF-RAY': '9f61c5bb4ba9ad9d-MRS', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
from bs4 import BeautifulSoup

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in C:\Users\Krish\anaconda3\Lib\site-packages (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in C:\Users\Krish\anaconda3\Lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\Krish\AppData\Roaming\Python\Python313\site-packages (from beautifulsoup4) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
with open(r"C:\Users\Krish\primebach\scraped_data\data1.html") as f:
    html_content = f.read()
    soup =BeautifulSoup(html_content,"lxml")

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_31940\3852920195.py in ?()
#       1 import pandas as pd
# ----> 2 df = pd.DataFrame('html_content')
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py in ?(self, data, index, columns, dtype, copy)
#     865                 )
#     866         # For data is scalar
#     867         else:
#     868             if index is None or columns is None:
# --> 869                 raise ValueError("DataFrame constructor not properly called!")
#     870
#     871             index = ensure_index(index)
#     872             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!
