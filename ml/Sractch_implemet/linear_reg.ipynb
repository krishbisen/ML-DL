# %%
import numpy as np

# %%
import numpy as np

class LinearRegression:
    def __init__(self, learning_rate=0.01, n_iter=1000):
        self.bias = None
        self.weights = None
        self.lr = learning_rate
        self.n_iter = n_iter

    def fit(self, X, y):
        m, n = X.shape          # no. of samples (rows) and no. of features (columns)

        # Step 1 - initialize parameters
        self.bias = 0
        self.weights = np.zeros(n)  # [0, 0, 0, ...]

        # Gradient descent
        for i in range(self.n_iter):

            # Step 2 - forward pass (predict)
            y_pred = self.bias + np.dot(X, self.weights)

            # Step 3 - compute gradients
            db = (1 / m) * np.sum(y_pred - y)
            dw = (1 / m) * np.dot(X.T, (y_pred - y))

            # Step 4 - update parameters (convergence)
            self.bias -= self.lr * db
            self.weights -= self.lr * dw

    def predict(self, X):
        y_pred = self.bias + np.dot(X, self.weights)
        return y_pred

# %%
X = np.array([[1],[2],[3],[4],[5]])
y = np.array([2,4,6,8, 10])

model = LinearRegression()
model.fit(X, y )
y_pred = model.predict(X)
print(y_pred)
# Out:
# [2.06850809 4.04226297 6.01601785 7.98977273 9.96352761]

# %%
model.bias, model.weights
# Out:
# (np.float64(0.09475321533750963), array([1.97375488]))

# %%
# linear reg with odl 
# ordinary least squarre
